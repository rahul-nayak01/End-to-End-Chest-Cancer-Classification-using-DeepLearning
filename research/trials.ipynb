# %%
print("h")
# Out:
# h

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1dNLrdRUZRskTkGegPY83mNzmq_4zeGwv/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1dNLrdRUZRskTkGegPY83mNzmq_4zeGwv'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest_ct_scan_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1dNLrdRUZRskTkGegPY83mNzmq_4zeGwv
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1dNLrdRUZRskTkGegPY83mNzmq_4zeGwv&confirm=t&uuid=ad9e4233-3450-45c7-8258-64cc6f7653a7
# To: c:\Users\nayak\OneDrive\Desktop\End-to-End-Chest-Cancer-Classification-using-DeepLearning\research\Chest_ct_scan_data.zip
# 100%|██████████| 49.0M/49.0M [00:10<00:00, 4.89MB/s]
# 'Chest_ct_scan_data.zip'
